# %% [markdown]
# # Relatório de análise III

# %% [markdown]
# ## Analisando discrepância nas colunas

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/home_credit-SELECTED-COLUMNS.csv')

# %%
dados
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0          100002       1         Cash loans           M            N
# 1          100003       0         Cash loans           F            N
# 2          100004       0    Revolving loans           M            Y
# 3          100006       0         Cash loans           F            N
# 4          100007       0         Cash loans           M            N
# ...           ...     ...                ...         ...          ...
# 99995      216086       0         Cash loans           F            N
# 99996      216087       0         Cash loans           F            N
# 99997      216088       0         Cash loans           F            Y
# 99998      216089       0         Cash loans           F            Y
# 99999      216090       0    Revolving loans           M            Y
#
#       FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...

# %%
columns = list(dados.columns)

# %%
columns
# Out:
# ['SK_ID_CURR',
#  'TARGET',
#  'NAME_CONTRACT_TYPE',
#  'CODE_GENDER',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'OWN_CAR_AGE',
#  'FLAG_WORK_PHONE',
#  'FLAG_CONT_MOBILE',
#  'FLAG_EMAIL',
#  'OCCUPATION_TYPE',
#  'CNT_FAM_MEMBERS',
#  'REGION_RATING_CLIENT',
#  'WEEKDAY_APPR_PROCESS_START',
#  'HOUR_APPR_PROCESS_START',
#  'ORGANIZATION_TYPE',
#  'HOUSETYPE_MODE',
#  'WALLSMATERIAL_MODE',
#  'EMERGENCYSTATE_MODE',
#  'DAYS_LAST_PHONE_CHANGE',
#  'AMT_REQ_CREDIT_BUREAU_HOUR',
#  'AMT_REQ_CREDIT_BUREAU_DAY',
#  'AMT_REQ_CREDIT_BUREAU_WEEK',
#  'AMT_REQ_CREDIT_BUREAU_MON',
#  'AMT_REQ_CREDIT_BUREAU_QRT',
#  'AMT_REQ_CREDIT_BUREAU_YEAR']

# %%
dados.dtypes
# Out:
# SK_ID_CURR                      int64
# TARGET                          int64
# NAME_CONTRACT_TYPE             object
# CODE_GENDER                    object
# FLAG_OWN_CAR                   object
# FLAG_OWN_REALTY                object
# CNT_CHILDREN                    int64
# AMT_INCOME_TOTAL              float64
# AMT_CREDIT                    float64
# AMT_ANNUITY                   float64
# AMT_GOODS_PRICE               float64
# NAME_EDUCATION_TYPE            object
# NAME_FAMILY_STATUS             object
# NAME_HOUSING_TYPE              object
# DAYS_BIRTH                      int64
# DAYS_EMPLOYED                   int64
# OWN_CAR_AGE                   float64
# FLAG_WORK_PHONE                 int64
# FLAG_CONT_MOBILE                int64
# FLAG_EMAIL                      int64
# OCCUPATION_TYPE                object
# CNT_FAM_MEMBERS               float64
# REGION_RATING_CLIENT            int64
# WEEKDAY_APPR_PROCESS_START     object
# HOUR_APPR_PROCESS_START         int64
# ...

# %% [markdown]
# Colunas que podem possuir discrepâncias:
#
# SK_ID_CURR                      int64
# TARGET                          int64
# CNT_CHILDREN                    int64
# AMT_INCOME_TOTAL              float64
# AMT_CREDIT                    float64
# AMT_ANNUITY                   float64
# AMT_GOODS_PRICE               float64
# DAYS_BIRTH                      int64
# DAYS_EMPLOYED                   int64
# OWN_CAR_AGE                   float64
# FLAG_WORK_PHONE                 int64
# FLAG_CONT_MOBILE                int64
# FLAG_EMAIL                      int64
# CNT_FAM_MEMBERS               float64
# REGION_RATING_CLIENT            int64
# HOUR_APPR_PROCESS_START         int64
# DAYS_LAST_PHONE_CHANGE        float64
# AMT_REQ_CREDIT_BUREAU_HOUR    float64
# AMT_REQ_CREDIT_BUREAU_DAY     float64
# AMT_REQ_CREDIT_BUREAU_WEEK    float64
# AMT_REQ_CREDIT_BUREAU_MON     float64
# AMT_REQ_CREDIT_BUREAU_QRT     float64
# AMT_REQ_CREDIT_BUREAU_YEAR    float64

# %%
dados['DAYS_BIRTH']
# Out:
# 0        -9461
# 1       -16765
# 2       -19046
# 3       -19005
# 4       -19932
#          ...
# 99995   -11838
# 99996   -13429
# 99997   -17626
# 99998   -12420
# 99999   -14808
# Name: DAYS_BIRTH, Length: 100000, dtype: int64

# %%
dados['DAYS_BIRTH'].drop_duplicates()
# Out:
# 0        -9461
# 1       -16765
# 2       -19046
# 3       -19005
# 4       -19932
#          ...
# 99596   -23254
# 99631   -24215
# 99646    -8305
# 99706   -24933
# 99910   -25039
# Name: DAYS_BIRTH, Length: 16971, dtype: int64

# %%
dados.sort_values(by = 'DAYS_BIRTH', inplace = True)
dados
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 63316      173431       0         Cash loans           F            N
# 79852      192568       0         Cash loans           F            N
# 65237      175658       0         Cash loans           F            N
# 49288      157055       0         Cash loans           F            Y
# 20863      124313       0         Cash loans           F            N
# ...           ...     ...                ...         ...          ...
# 48401      156053       1         Cash loans           M            Y
# 73870      185672       0         Cash loans           M            N
# 65419      175871       0    Revolving loans           F            N
# 19115      122300       0    Revolving loans           F            N
# 53702      162210       0         Cash loans           M            N
#
#       FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...
